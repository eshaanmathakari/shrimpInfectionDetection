# %% [markdown]
# <a href="https://colab.research.google.com/github/eshaanmathakari/shrimpInfectionDetection/blob/main/datapipeline_shrimpDet.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install Augmentor
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#connecting dataset with code
import Augmentor
p = Augmentor.Pipeline("/content/drive/Shareddrives/Major_Project/Image_dataset/train/healthy")
# Out:
# Initialised with 574 image(s) found.
# Output directory set to /content/drive/Shareddrives/Major_Project/Image_dataset/train/healthy/output.

# %%
#performing rotations on images
p.rotate(probability=0.7, max_left_rotation=10, max_right_rotation=10)

# %%
#performing zoom-in zoom-out on images
p.zoom(probability=0.3, min_factor=1.1, max_factor=1.6)

# %%
#taking 500 images as new training dataset
#PS- 500 was just an example I took, we can increase it according to our necssities

training_augmented = p.sample(500)
# Out:
# Processing <PIL.Image.Image image mode=RGB size=4624x3468 at 0x7F294059F730>: 100%|██████████| 500/500 [03:06<00:00,  2.68 Samples/s]

# %%
# !zip -r /content/drive/Shareddrives/Major_Project/Image_dataset/train/healthy/output.zip /content/drive/Shareddrives/Major_Project/Image_dataset/train/healthy/output
# Out:
#   adding: content/drive/Shareddrives/Major_Project/Image_dataset/train/healthy/output/ (stored 0%)
#   adding: content/drive/Shareddrives/Major_Project/Image_dataset/train/healthy/output/healthy_original_healthy_original_istockphoto-506012856-612x612_jpg.rf.5fb47e132c4fbabc093d1af80c6d5d7e.jpg_cff5dfb7-4f3d-4f57-a035-c005b25819b9.jpg_839e4b77-a637-494a-8332-fedbc9dedafb.jpg (deflated 5%)
#   adding: content/drive/Shareddrives/Major_Project/Image_dataset/train/healthy/output/healthy_original_healthy_original_Screenshot-2022-03-23-134301_jpg.rf.e3b995022b14424de43372169821cc33.jpg_204a8b92-c97c-43f2-af1d-d737ce709825.jpg_89fcc8b9-816c-45d1-959a-3a59c826e3f7.jpg (deflated 8%)
#   adding: content/drive/Shareddrives/Major_Project/Image_dataset/train/healthy/output/healthy_original_healthy_original_istockphoto-506012856-612x612_jpg.rf.5fb47e132c4fbabc093d1af80c6d5d7e.jpg_2bd17427-14d7-4908-b81c-0cbe0d909b9d.jpg_d8117c2c-015b-4ae8-a9e5-9fcdf16118ca.jpg (deflated 3%)
# ...

# %%
from google.colab import files
files.download('/content/drive/Shareddrives/Major_Project/Image_dataset/train/healthy/output.zip')
